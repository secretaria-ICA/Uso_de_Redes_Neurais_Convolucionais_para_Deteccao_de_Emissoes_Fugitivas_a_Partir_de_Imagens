# %%
from google.colab import drive
drive.mount('/content/drive')
import os
workdir_path = '/content/drive/My Drive/Finalmono' #Modifiquei para o meu workplace
os.chdir(workdir_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Nova seção

# %%
import sys
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import glob
from imutils import paths

# %%
INIT_LR = 1e-3
EPOCHS = 200 # PODE MUDAR
BS = 8

# %%
# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images 
dataset_path = 'Fugitivas'
print("[INFO] loading images...")
imagePaths = list(paths.list_images(dataset_path))
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over the image paths
for imagePath in imagePaths:
    # extract the class label from the filename
    label = imagePath.split(os.path.sep)[-2]
    
    # load the image, swap color channels, and resize it to be a fixed
    # 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))
    
    # update the data and labels lists, respectively
    data.append(image)
    labels.append(label)
print("labels: ", np.unique(labels))
# Out:
# labels:  ['COMfugitivas' 'SEMfugitivas']

# %%
# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 255]
data = np.array(data) / 255.0
labels = np.array(labels)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(data[labels=='SEMfugitivas'][3])
plt.show()

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels, 
                                                  test_size=0.50, 
                                                  stratify=labels, 
                                                  random_state=42)

# %%
# initialize the training data augmentation object
trainAug = ImageDataGenerator(rotation_range=30, fill_mode="nearest")

# %%
# load the VGG16 network, ensuring the head FC layer sets are left
# off
baseModel = VGG16(weights="imagenet", include_top=False,
                  input_tensor=Input(shape=(224, 224, 3)))

# marcar camadas como não treináveis
for layer in baseModel.layers:
    layer.trainable = False

# adicionar novas camadas para classificação
flat1 = Flatten()(baseModel.layers[-1].output)
# class1 = Dense(128, activation='relu', kernel_initializer='he_uniform')(flat1)
output = Dense(2, activation='softmax')(flat1)

# definir o modelo
model = Model(inputs=baseModel.inputs, outputs=output)

# compilar modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Visualizar o modelo compilado
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
baseModel = VGG16(weights="imagenet", include_top=False,
                  input_tensor=Input(shape=(224, 224, 3)))

f1 = baseModel.layers[1].output
f2 = baseModel.layers[2].output
f3 = baseModel.layers[4].output
f4 = baseModel.layers[5].output
feature_maps = Model(inputs=baseModel.input, outputs=[f1, f2, f3, f4])

# %%
y = np.argmax(trainY, axis=-1)

# %%
feat1, feat2, feat3, feat4 = feature_maps.predict(trainX[y==1][0:1])

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].imshow(feat1[0, :, :, 0:3])
axs[0, 1].imshow(feat2[0, :, :, 6:9])
axs[1, 0].imshow(feat3[0, :, :, 0:3])
axs[1, 1].imshow(feat4[0, :, :, 3:6])
# plt.subplots
# plt.imshow(feat1[0, :, :, 0:3])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# train the head of the network
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint('best4.h5', monitor='val_accuracy', save_best_only=True)

print("[INFO] training head...")
H = model.fit_generator(
    trainAug.flow(trainX, trainY, batch_size=BS),
    steps_per_epoch=len(trainX) // BS,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BS,
    epochs=EPOCHS,
    callbacks=[checkpoint])
# Out:
# [INFO] training head...
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2/2 [==============================] - 16s 14s/step - loss: 0.6515 - accuracy: 0.7000 - val_loss: 1.1495 - val_accuracy: 0.5263
# Epoch 2/200
# 2/2 [==============================] - 15s 14s/step - loss: 1.5305 - accuracy: 0.5000 - val_loss: 1.2123 - val_accuracy: 0.5263
# Epoch 3/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.6893 - accuracy: 0.6000 - val_loss: 0.5931 - val_accuracy: 0.7368
# Epoch 4/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.6526 - accuracy: 0.7000 - val_loss: 0.7361 - val_accuracy: 0.4737
# Epoch 5/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.7096 - accuracy: 0.5625 - val_loss: 0.6043 - val_accuracy: 0.5789
# Epoch 6/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.3768 - accuracy: 0.8000 - val_loss: 0.6437 - val_accuracy: 0.6842
# Epoch 7/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.4731 - accuracy: 0.6875 - val_loss: 0.7873 - val_accuracy: 0.6316
# Epoch 8/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.3502 - accuracy: 0.8000 - val_loss: 0.7216 - val_accuracy: 0.6316
# Epoch 9/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.3514 - accuracy: 0.8750 - val_loss: 0.6064 - val_accuracy: 0.6842
# Epoch 10/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.2689 - accuracy: 0.8750 - val_loss: 0.5643 - val_accuracy: 0.6316
# Epoch 11/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1649 - accuracy: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.5789
# Epoch 12/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.2273 - accuracy: 0.9000 - val_loss: 0.6946 - val_accuracy: 0.5789
# Epoch 13/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.3564 - accuracy: 0.7000 - val_loss: 0.6328 - val_accuracy: 0.6316
# Epoch 14/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.2206 - accuracy: 0.9000 - val_loss: 0.5705 - val_accuracy: 0.5789
# Epoch 15/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.1409 - accuracy: 1.0000 - val_loss: 0.6117 - val_accuracy: 0.6842
# Epoch 16/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1487 - accuracy: 0.9000 - val_loss: 0.5975 - val_accuracy: 0.6842
# Epoch 17/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1164 - accuracy: 1.0000 - val_loss: 0.5637 - val_accuracy: 0.6316
# Epoch 18/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.2024 - accuracy: 0.9000 - val_loss: 0.5485 - val_accuracy: 0.6316
# Epoch 19/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1809 - accuracy: 0.9000 - val_loss: 0.5596 - val_accuracy: 0.6316
# Epoch 20/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.1585 - accuracy: 0.9375 - val_loss: 0.5727 - val_accuracy: 0.6316
# Epoch 21/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0893 - accuracy: 1.0000 - val_loss: 0.5628 - val_accuracy: 0.6316
# Epoch 22/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.1199 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.6316
# Epoch 23/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1597 - accuracy: 1.0000 - val_loss: 0.5495 - val_accuracy: 0.6316
# Epoch 24/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0896 - accuracy: 1.0000 - val_loss: 0.5587 - val_accuracy: 0.7368
# Epoch 25/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1383 - accuracy: 0.9000 - val_loss: 0.5857 - val_accuracy: 0.6842
# Epoch 26/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.5896 - val_accuracy: 0.6842
# Epoch 27/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.1528 - accuracy: 0.9000 - val_loss: 0.5411 - val_accuracy: 0.5789
# Epoch 28/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.5698 - val_accuracy: 0.6316
# Epoch 29/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.1266 - accuracy: 1.0000 - val_loss: 0.6263 - val_accuracy: 0.5789
# Epoch 30/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 0.6618 - val_accuracy: 0.5789
# Epoch 31/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.1070 - accuracy: 1.0000 - val_loss: 0.6382 - val_accuracy: 0.5789
# Epoch 32/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0968 - accuracy: 1.0000 - val_loss: 0.5450 - val_accuracy: 0.6316
# Epoch 33/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.1134 - accuracy: 1.0000 - val_loss: 0.5827 - val_accuracy: 0.7368
# Epoch 34/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.6563 - val_accuracy: 0.6842
# Epoch 35/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.7171 - val_accuracy: 0.5789
# Epoch 36/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.7147 - val_accuracy: 0.5789
# Epoch 37/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0891 - accuracy: 0.9375 - val_loss: 0.6070 - val_accuracy: 0.6842
# Epoch 38/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0870 - accuracy: 0.9375 - val_loss: 0.5348 - val_accuracy: 0.6842
# Epoch 39/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.7368
# Epoch 40/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.1289 - accuracy: 1.0000 - val_loss: 0.5476 - val_accuracy: 0.6842
# Epoch 41/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.5240 - val_accuracy: 0.6842
# Epoch 42/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.6316
# Epoch 43/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.6842
# Epoch 44/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.5217 - val_accuracy: 0.6842
# Epoch 45/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.5270 - val_accuracy: 0.6842
# Epoch 46/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.7368
# Epoch 47/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 0.6842
# Epoch 48/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.5966 - val_accuracy: 0.6842
# Epoch 49/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0892 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.6842
# Epoch 50/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.1382 - accuracy: 0.9000 - val_loss: 0.5683 - val_accuracy: 0.6842
# Epoch 51/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.5400 - val_accuracy: 0.7368
# Epoch 52/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.5203 - val_accuracy: 0.6842
# Epoch 53/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.6842
# Epoch 54/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.6842
# Epoch 55/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.5482 - val_accuracy: 0.6842
# Epoch 56/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.6081 - val_accuracy: 0.5789
# Epoch 57/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.6374 - val_accuracy: 0.5789
# Epoch 58/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.6401 - val_accuracy: 0.5789
# Epoch 59/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.6353 - val_accuracy: 0.5789
# Epoch 60/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0632 - accuracy: 1.0000 - val_loss: 0.5937 - val_accuracy: 0.6316
# Epoch 61/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0862 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.6842
# Epoch 62/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.5259 - val_accuracy: 0.7368
# Epoch 63/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.5210 - val_accuracy: 0.6842
# Epoch 64/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.5317 - val_accuracy: 0.7368
# Epoch 65/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.5593 - val_accuracy: 0.7368
# Epoch 66/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.5555 - val_accuracy: 0.7368
# Epoch 67/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.7368
# Epoch 68/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.5276 - val_accuracy: 0.7368
# Epoch 69/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.5047 - val_accuracy: 0.6842
# Epoch 70/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.7368
# Epoch 71/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.7368
# Epoch 72/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 0.6316
# Epoch 73/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.4789 - val_accuracy: 0.6842
# Epoch 74/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.7895
# Epoch 75/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.7895
# Epoch 76/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.7895
# Epoch 77/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.4674 - val_accuracy: 0.7895
# Epoch 78/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.4664 - val_accuracy: 0.8421
# Epoch 79/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.4658 - val_accuracy: 0.8421
# Epoch 80/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.8421
# Epoch 81/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.8421
# Epoch 82/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.4656 - val_accuracy: 0.7368
# Epoch 83/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.8421
# Epoch 84/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.4619 - val_accuracy: 0.8421
# Epoch 85/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.7895
# Epoch 86/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.7895
# Epoch 87/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.4602 - val_accuracy: 0.8421
# Epoch 88/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.4769 - val_accuracy: 0.7368
# Epoch 89/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.5046 - val_accuracy: 0.6842
# Epoch 90/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.5143 - val_accuracy: 0.6842
# Epoch 91/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.5104 - val_accuracy: 0.6842
# Epoch 92/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.5019 - val_accuracy: 0.6842
# Epoch 93/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.6842
# Epoch 94/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.6842
# Epoch 95/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.4581 - val_accuracy: 0.7895
# Epoch 96/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.4464 - val_accuracy: 0.8421
# Epoch 97/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4495 - val_accuracy: 0.7895
# Epoch 98/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.4566 - val_accuracy: 0.7368
# Epoch 99/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4492 - val_accuracy: 0.7895
# Epoch 100/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.4448 - val_accuracy: 0.8421
# Epoch 101/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4434 - val_accuracy: 0.8421
# Epoch 102/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4441 - val_accuracy: 0.7895
# Epoch 103/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.7895
# Epoch 104/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.7895
# Epoch 105/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4669 - val_accuracy: 0.7368
# Epoch 106/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.7368
# Epoch 107/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4736 - val_accuracy: 0.7368
# Epoch 108/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4676 - val_accuracy: 0.7368
# Epoch 109/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0399 - accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.8421
# Epoch 110/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.7895
# Epoch 111/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.7368
# Epoch 112/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.4728 - val_accuracy: 0.7368
# Epoch 113/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.7368
# Epoch 114/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4834 - val_accuracy: 0.7368
# Epoch 115/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.7368
# Epoch 116/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.7895
# Epoch 117/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.4572 - val_accuracy: 0.7895
# Epoch 118/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.4528 - val_accuracy: 0.7895
# Epoch 119/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.4516 - val_accuracy: 0.8421
# Epoch 120/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.8421
# Epoch 121/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.8421
# Epoch 122/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4632 - val_accuracy: 0.8421
# Epoch 123/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.7895
# Epoch 124/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4636 - val_accuracy: 0.7895
# Epoch 125/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4612 - val_accuracy: 0.8421
# Epoch 126/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4571 - val_accuracy: 0.8421
# Epoch 127/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8421
# Epoch 128/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4526 - val_accuracy: 0.8421
# Epoch 129/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.7895
# Epoch 130/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4469 - val_accuracy: 0.8421
# Epoch 131/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.7895
# Epoch 132/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4460 - val_accuracy: 0.7895
# Epoch 133/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.7895
# Epoch 134/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4460 - val_accuracy: 0.7895
# Epoch 135/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.7895
# Epoch 136/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4552 - val_accuracy: 0.7895
# Epoch 137/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4624 - val_accuracy: 0.7895
# Epoch 138/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.4683 - val_accuracy: 0.7368
# Epoch 139/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4715 - val_accuracy: 0.7368
# Epoch 140/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.4720 - val_accuracy: 0.7368
# Epoch 141/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.7895
# Epoch 142/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.7895
# Epoch 143/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.7895
# Epoch 144/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4526 - val_accuracy: 0.8421
# Epoch 145/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4562 - val_accuracy: 0.8421
# Epoch 146/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4552 - val_accuracy: 0.8421
# Epoch 147/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.8421
# Epoch 148/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4493 - val_accuracy: 0.7895
# Epoch 149/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4583 - val_accuracy: 0.7895
# Epoch 150/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.7895
# Epoch 151/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.7895
# Epoch 152/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4713 - val_accuracy: 0.7895
# Epoch 153/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.7895
# Epoch 154/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.7895
# Epoch 155/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4595 - val_accuracy: 0.7895
# Epoch 156/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.7895
# Epoch 157/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4619 - val_accuracy: 0.8421
# Epoch 158/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4659 - val_accuracy: 0.8947
# Epoch 159/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.7895
# Epoch 160/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4807 - val_accuracy: 0.7895
# Epoch 161/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.7895
# Epoch 162/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.7368
# Epoch 163/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4926 - val_accuracy: 0.7368
# Epoch 164/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5001 - val_accuracy: 0.6842
# Epoch 165/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.6842
# Epoch 166/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.4960 - val_accuracy: 0.6842
# Epoch 167/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4851 - val_accuracy: 0.7895
# Epoch 168/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.7895
# Epoch 169/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4568 - val_accuracy: 0.8421
# Epoch 170/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4474 - val_accuracy: 0.8421
# Epoch 171/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4429 - val_accuracy: 0.7895
# Epoch 172/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.4412 - val_accuracy: 0.7895
# Epoch 173/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4404 - val_accuracy: 0.7895
# Epoch 174/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.7895
# Epoch 175/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4380 - val_accuracy: 0.8421
# Epoch 176/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4396 - val_accuracy: 0.8421
# Epoch 177/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.8421
# Epoch 178/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4496 - val_accuracy: 0.7895
# Epoch 179/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4553 - val_accuracy: 0.7895
# Epoch 180/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4617 - val_accuracy: 0.7895
# Epoch 181/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.7895
# Epoch 182/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4669 - val_accuracy: 0.7895
# Epoch 183/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.7895
# Epoch 184/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.7895
# Epoch 185/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4420 - val_accuracy: 0.7895
# Epoch 186/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4355 - val_accuracy: 0.8421
# Epoch 187/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4324 - val_accuracy: 0.7895
# Epoch 188/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4313 - val_accuracy: 0.8421
# Epoch 189/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4323 - val_accuracy: 0.7895
# Epoch 190/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4468 - val_accuracy: 0.7895
# Epoch 191/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.7895
# Epoch 192/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4816 - val_accuracy: 0.7368
# Epoch 193/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.7368
# Epoch 194/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.4707 - val_accuracy: 0.7895
# Epoch 195/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.4477 - val_accuracy: 0.7895
# Epoch 196/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4421 - val_accuracy: 0.7895
# Epoch 197/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.8421
# Epoch 198/200
# 2/2 [==============================] - 15s 14s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.8421
# Epoch 199/200
# 2/2 [==============================] - 18s 14s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4566 - val_accuracy: 0.7895
# Epoch 200/200
# 2/2 [==============================] - 15s 11s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4585 - val_accuracy: 0.7895

# %%
model.load_weights("best4.h5")

# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs,
                            target_names=lb.classes_))

# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
total = sum(sum(cm))
accuracy = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)
print("accuracy: {:.4f}".format(accuracy))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
# COMfugitivas       0.90      0.90      0.90        10
# SEMfugitivas       0.89      0.89      0.89         9
#
#     accuracy                           0.89        19
#    macro avg       0.89      0.89      0.89        19
# weighted avg       0.89      0.89      0.89        19
#
# [[9 1]
#  [1 8]]
# accuracy: 0.8947
# sensitivity: 0.9000
# specificity: 0.8889

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.title("Training Loss on Fugitivas Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.show()

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_accuracy")
plt.title("Training Accuracy on Fugitivas Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()
